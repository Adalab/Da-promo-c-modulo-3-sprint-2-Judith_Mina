# %%
import pandas as pd
import numpy as np
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
df = pd.read_csv("monumentos_europa.csv", index_col=0).reset_index()

# %%
df.drop("index", axis=1,inplace=True)

# %%
df
# Out:
#                                              nombre                ciudad  \
# 0                            Catedral de Notre Dame                 París
# 1                             Basílica de San Pedro   Ciudad del Vaticano
# 2                      Basílica del Sagrado Corazón                 París
# 3                                  Museo del Louvre                 París
# 4             Santuario de Nuestra Señora de Fátima                 Ourém
# 5                              Palacio de Versalles             Versalles
# 6                                           Coliseo                  Roma
# 7                                          Partenón                Atenas
# 8                                      Torre Eiffel                 París
# 9                                           Panteón                  Roma
# 10                                 Museos Vaticanos   Ciudad del Vaticano
# 11  Santuario del Padre Pío en San Giovanni Rotondo  San Giovanni Rotondo
# ...

# %%
null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
display(df[df.isnull().any(axis=1)][null_columns])
# Out:
#    visitantes_año  año_conteo
# 7             NaN      2019.0
# 16            NaN      2018.0
# 17            NaN      2012.0
# 19            NaN      2018.0
# 24            NaN      2020.0
# 34            NaN      2018.0
# 35            NaN         NaN

# %%
df.iloc[7,2] = "8500200"  # = 8500200
df.iloc[16,2] = "6200000"
df.iloc[17,2] = "5835027"
df.iloc[19,2] = "9350000"
df.iloc[24,2] = "10500000"
df.iloc[34,2] = "7250000"
df.iloc[35,[2,3]] = ["4500000", 2016]

# %%
df
# Out:
#                                              nombre                ciudad  \
# 0                            Catedral de Notre Dame                 París
# 1                             Basílica de San Pedro   Ciudad del Vaticano
# 2                      Basílica del Sagrado Corazón                 París
# 3                                  Museo del Louvre                 París
# 4             Santuario de Nuestra Señora de Fátima                 Ourém
# 5                              Palacio de Versalles             Versalles
# 6                                           Coliseo                  Roma
# 7                                          Partenón                Atenas
# 8                                      Torre Eiffel                 París
# 9                                           Panteón                  Roma
# 10                                 Museos Vaticanos   Ciudad del Vaticano
# 11  Santuario del Padre Pío en San Giovanni Rotondo  San Giovanni Rotondo
# ...

# %%
null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
display(df[df.isnull().any(axis=1)][null_columns])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lista_año_construccion= [1163, 1506, 1923, 1793, 1928, 1634, 72, -447, 1887, 125, 1506, 1861, 1823, 2006, 1824, 1858, 1248, 1228, 1873, 1703, 832, 1852, 1882, 1473, 1296, 1756, 1382, 1581, 1852, 1986, 1857, 1977, 1796, 1677, 1700, 1848, 1785, 1850, 1100, 1492, 1994 ]

# %%
df["año_construccion"] = lista_año_construccion

# %%
estilo_arquitectonico= ['Gótica', 'Neobarroca', 'Neobizantina', 'Barroca','Neobarroca','Barroca', 'Romana', 'Romana', 'Del hierro','Romana', 'Renacentista', 'Moderna','Neoclásica', 'Contemporánea','Postmodernista', 'Romana', 'Gótica', 'Mudéjar', 'Neogótica', 'Barroca', 'Gótica','Palladianismo','Gótica', 'Renacentista' , 'Renacentista', 'Neoclásica', 'Renacentista','Renacentista','Eclética','Neogótica', 'Neogótica', 'Contemporánea', 'Neoclásica', 'Barroca', 'Barroca','Tártara', 'Neoclásica', 'Estalinista', 'Neogótica', 'Islámica', 'Moderna']

# %%
df["estilo"] = estilo_arquitectonico

# %%
df
# Out:
#                                              nombre                ciudad  \
# 0                            Catedral de Notre Dame                 París
# 1                             Basílica de San Pedro   Ciudad del Vaticano
# 2                      Basílica del Sagrado Corazón                 París
# 3                                  Museo del Louvre                 París
# 4             Santuario de Nuestra Señora de Fátima                 Ourém
# 5                              Palacio de Versalles             Versalles
# 6                                           Coliseo                  Roma
# 7                                          Partenón                Atenas
# 8                                      Torre Eiffel                 París
# 9                                           Panteón                  Roma
# 10                                 Museos Vaticanos   Ciudad del Vaticano
# 11  Santuario del Padre Pío en San Giovanni Rotondo  San Giovanni Rotondo
# ...

# %%
df["año_conteo"] = df["año_conteo"].astype("Int64")

# %%
df["visitantes_año"] = df["visitantes_año"].str.replace(" ", "")

# %%
df["visitantes_año"] = df["visitantes_año"].astype("Int64")

# %%
df.iloc[7,4] = "Grecia"  # = 8500200

# %%
df.to_csv("monumentos_europa_1.csv")

# %% [markdown]
# - Comparar los monumentos del pais con las visitas

# %%
df2 = pd.read_csv("monumentos_europa_2.csv", index_col=0)

# %%
df2
# Out:
#                                                 nombre           ciudad  \
# 111                            Royal Museums Greenwich        Greenwich
# 117                 Museo de la batalla de Stalingrado            Rusia
# 121                                        Rijksmuseum        Ámsterdam
# 125                Cité des sciences et de l'industrie            París
# 126                          Museo Nacional de Escocia        Edimburgo
# 127                                 Museo Estatal Ruso  San Petersburgo
# 129                     Galerías nacionales de Escocia        Edimburgo
# 130                                     Museo Van Gogh        Ámsterdam
# 131                                  Galería Tretiakov            Moscú
# 133                              Castillo de Edimburgo        Edimburgo
# 134                                   Palacio Lazienki         Varsovia
# 135                   Museo estatal Auschwitz-Birkenau        Auschwitz
# ...

# %%
df2.drop(136, axis=0, inplace= True)

# %%
años_construc= [1635,1995,1876,1986,1861,1895,1859,1964,1856, 1130, 1689,1947 ,1953, 786,1356,1675,1806, 1735,1869,1936]

# %%
df2["año_construccion"] = años_construc

# %%
lista_arquitectura = ["Barroco Inglés",
                     "Industrial",
                     "Neogótico Holandés",
                     "Moderno",
                     "Neorrománico",
                     "Neoclásico",
                     "Neoclásico",
                     "Moderno",
                     "Constructivista",
                     "Medieval Escocesa",
                     "Neoclásico",
                     "Industrial",
                     "Neogótico",
                     "Islámico",
                     "Islámico, Renacentista",
                     "Renacimiento, Barroco Inglés",
                     "Neoclásico",
                     "Barroco, Clásico",
                     "Neorrománico",
                     "Neogótico"]

# %%
df2["estilo"] = lista_arquitectura

# %%
df2["visitantes_año"] = df2["visitantes_año"].str.replace(" ", "")

# %%
#pd.to_numeric(df2["visitantes_año"], )

# %%
df2["visitantes_año"] = df2["visitantes_año"].astype("float")

# %%
df2["visitantes_año"] = df2["visitantes_año"].astype("Int64")

# %%
df2
# Out:
#                                                 nombre           ciudad  \
# 111                            Royal Museums Greenwich        Greenwich
# 117                 Museo de la batalla de Stalingrado            Rusia
# 121                                        Rijksmuseum        Ámsterdam
# 125                Cité des sciences et de l'industrie            París
# 126                          Museo Nacional de Escocia        Edimburgo
# 127                                 Museo Estatal Ruso  San Petersburgo
# 129                     Galerías nacionales de Escocia        Edimburgo
# 130                                     Museo Van Gogh        Ámsterdam
# 131                                  Galería Tretiakov            Moscú
# 133                              Castillo de Edimburgo        Edimburgo
# 134                                   Palacio Lazienki         Varsovia
# 135                   Museo estatal Auschwitz-Birkenau        Auschwitz
# ...

# %%
df_total = pd.concat([df,df2], axis=0).reset_index()

# %%
df_total
# Out:
#     index                                             nombre  \
# 0       0                             Catedral de Notre Dame
# 1       1                              Basílica de San Pedro
# 2       2                       Basílica del Sagrado Corazón
# 3       3                                   Museo del Louvre
# 4       4              Santuario de Nuestra Señora de Fátima
# 5       5                               Palacio de Versalles
# 6       6                                            Coliseo
# 7       7                                           Partenón
# 8       8                                       Torre Eiffel
# 9       9                                            Panteón
# 10     10                                   Museos Vaticanos
# 11     11    Santuario del Padre Pío en San Giovanni Rotondo
# 12     12                                    Museo Británico
# 13     13                                        Tate Modern
# ...

# %%
estilo_arquitectonico= ['Gótica', 'Neobarroca', 'Neobizantina', 'Barroca','Neobarroca','Barroca', 'Romana', 'Romana', 'Del hierro','Romana', 'Renacentista', 'Moderna','Neoclásica', 'Contemporánea','Postmodernista', 'Romana', 'Gótica', 'Mudéjar', 'Neogótica', 'Barroca', 'Gótica','Palladianismo','Gótica', 'Renacentista' , 'Renacentista', 'Neoclásica', 'Renacentista','Renacentista','Eclética','Neogótica', 'Neogótica', 'Contemporánea', 'Neoclásica', 'Barroca', 'Barroca','Tártara', 'Neoclásica', 'Estalinista', 'Neogótica', 'Islámica', 'Moderna','Barroco Inglés','Industrial','Neogótico','Contemporáneo','Neorrománico','Neoclásico', 'Neoclásico','Contemporáneo', 'Constructivista','Medieval', 'Neoclásica', 'Industrial', 'Neogótica','Islámica','Islámica','Renacimiento','Neoclásica','Barroca','Neorrománica', 'Neogótica' ]

# %%
df_total["estilo"] = estilo_arquitectonico

# %%
df_total
# Out:
#     index                                             nombre  \
# 0       0                             Catedral de Notre Dame
# 1       1                              Basílica de San Pedro
# 2       2                       Basílica del Sagrado Corazón
# 3       3                                   Museo del Louvre
# 4       4              Santuario de Nuestra Señora de Fátima
# 5       5                               Palacio de Versalles
# 6       6                                            Coliseo
# 7       7                                           Partenón
# 8       8                                       Torre Eiffel
# 9       9                                            Panteón
# 10     10                                   Museos Vaticanos
# 11     11    Santuario del Padre Pío en San Giovanni Rotondo
# 12     12                                    Museo Británico
# 13     13                                        Tate Modern
# ...

# %%
df_total.drop("index", axis=1, inplace=True)

# %%
#df_total

# %%
#df_total.rename({'nombre':'monumento'}, axis=1, inplace=True)

# %%
df_total.to_csv("monumentos_europa_3.csv")

# %%
df_demo= df_total.copy()

# %%
len(df_demo)
# Out:
# 61

# %%
df_demo.drop(['ciudad',	'visitantes_año',	'año_conteo',	'pais_corto',	'continente',	'año_construccion',	'estilo'], axis=1, inplace=True)

# %%
df_demo.head(165)
# Out:
#                                                nombre
# 0                              Catedral de Notre Dame
# 1                               Basílica de San Pedro
# 2                        Basílica del Sagrado Corazón
# 3                                    Museo del Louvre
# 4               Santuario de Nuestra Señora de Fátima
# 5                                Palacio de Versalles
# 6                                             Coliseo
# 7                                            Partenón
# 8                                        Torre Eiffel
# 9                                             Panteón
# 10                                   Museos Vaticanos
# 11    Santuario del Padre Pío en San Giovanni Rotondo
# 12                                    Museo Británico
# 13                                        Tate Modern
# 14                        National Gallery de Londres
# 15             Santuario de Nuestra Señora de Lourdes
# ...

# %%
imagenes = ["https://es.wikipedia.org/wiki/Catedral_de_Notre_Dame_%28Par%C3%ADs%29#/media/Archivo:Notre-Dame_de_Paris_2013-07-24.jpg", 
"https://es.wikipedia.org/wiki/Bas%C3%ADlica_de_San_Pedro#/media/Archivo:Basilica_di_San_Pietro_in_Vaticano_September_2015-1a.jpg", 
"https://es.wikipedia.org/wiki/Bas%C3%ADlica_del_Sagrado_Coraz%C3%B3n_(Par%C3%ADs)#/media/Archivo:Sacre_Coeur_1.JPG", 
"https://es.wikipedia.org/wiki/Museo_del_Louvre#/media/Archivo:Louvre_Museum_Wikimedia_Commons.jpg", 
"https://es.wikipedia.org/wiki/Santuario_de_F%C3%A1tima#/media/Archivo:Sanctuary_of_Fatima.jpg",
"https://es.wikipedia.org/wiki/Palacio_de_Versalles#/media/Archivo:Vue_a%C3%A9rienne_du_domaine_de_Versailles_par_ToucanWings_-_Creative_Commons_By_Sa_3.0_-_083.jpg",
"https://es.wikipedia.org/wiki/Coliseo#/media/Archivo:Colosseo_2020.jpg" ,
"https://es.wikipedia.org/wiki/Archivo:The_Parthenon_in_Athens.jpg",
"https://es.wikipedia.org/wiki/Archivo:Eiffelturm.JPG" ,
"https://es.wikipedia.org/wiki/Pante%C3%B3n_de_Agripa#/media/Archivo:Pantheon_Rom_1_cropped.jpg",
"https://es.wikipedia.org/wiki/Museos_Vaticanos#/media/Archivo:Rome_Vatican_Museums.jpg", 
"https://www.holyart.es/blog/wp-content/uploads/sites/13/2021/09/Santuario-de-Padre-P%C3%ADo-en-San-Giovanni-Rotondo.jpg",
"https://es.wikipedia.org/wiki/Museo_Brit%C3%A1nico#/media/Archivo:British_Museum_from_NE_2.JPG", 
"https://es.wikipedia.org/wiki/Tate_Modern#/media/Archivo:Tate_Modern_viewed_from_Thames_Pleasure_Boat_-_geograph.org.uk_-_307445.jpg", 
"https://es.wikipedia.org/wiki/National_Gallery#/media/Archivo:Galer%C3%ADa_Nacional,_Londres,_Inglaterra,_2014-08-07,_DD_036.JPG", 
"https://es.wikipedia.org/wiki/Santuario_de_Lourdes#/media/Archivo:Lourdes_-_Santuario_visto_dal_forte.JPG",
"https://es.wikipedia.org/wiki/Catedral_de_Colonia#/media/Archivo:K%C3%B6lner_Dom_von_Osten.jpg",
"https://www.tretyakovgallery.ru/",
"https://es.wikipedia.org/wiki/Castillo_de_Edimburgo",
"https://www.lazienki-krolewskie.pl/pl",
"https://www.auschwitz.org/en/more/spanish/",
"https://www.chapellenotredamedelamedaillemiraculeuse.com/langues/espanol/capilla-nuestra-senora-de-la-medalla-milagrosa/",
"https://mezquita-catedraldecordoba.es/",
"https://www.alcazarsevilla.org/",
"https://www.stpauls.co.uk/",
"https://www.paris-arc-de-triomphe.fr/es/",
"https://www.patrimonionacional.es/visita/palacio-real-de-madrid",
"https://www.neuschwanstein.de/spanisch/visitante/index.htm",
"https://www.milan-museum.com/es/duomo-catedral-de-milan.php"]

# %%
df_demo["enlace"] = enlaces

# %%
df_demo
# Out:
#                                                nombre  \
# 0                              Catedral de Notre Dame
# 1                               Basílica de San Pedro
# 2                        Basílica del Sagrado Corazón
# 3                                    Museo del Louvre
# 4               Santuario de Nuestra Señora de Fátima
# 5                                Palacio de Versalles
# 6                                             Coliseo
# 7                                            Partenón
# 8                                        Torre Eiffel
# 9                                             Panteón
# 10                                   Museos Vaticanos
# 11    Santuario del Padre Pío en San Giovanni Rotondo
# 12                                    Museo Británico
# 13                                        Tate Modern
# 14                        National Gallery de Londres
# 15             Santuario de Nuestra Señora de Lourdes
# ...

# %%
df_demo.to_csv("monumentos_anexo_1.csv")

# %% [markdown]
# ### Imagenes
#
#
#
# 0. "https://es.wikipedia.org/wiki/Catedral_de_Notre_Dame_%28Par%C3%ADs%29#/media/Archivo:Notre-Dame_de_Paris_2013-07-24.jpg",
# 1. "https://es.wikipedia.org/wiki/Bas%C3%ADlica_de_San_Pedro#/media/Archivo:Basilica_di_San_Pietro_in_Vaticano_September_2015-1a.jpg",
# 2. "https://es.wikipedia.org/wiki/Bas%C3%ADlica_del_Sagrado_Coraz%C3%B3n_(Par%C3%ADs)#/media/Archivo:Sacre_Coeur_1.JPG",
# 3. "https://es.wikipedia.org/wiki/Museo_del_Louvre#/media/Archivo:Louvre_Museum_Wikimedia_Commons.jpg",
# 4. "https://es.wikipedia.org/wiki/Santuario_de_F%C3%A1tima#/media/Archivo:Sanctuary_of_Fatima.jpg",
# 5. Palacio de Versailles:      "https://es.wikipedia.org/wiki/Palacio_de_Versalles#/media/Archivo:Vue_a%C3%A9rienne_du_domaine_de_Versailles_par_ToucanWings_-_Creative_Commons_By_Sa_3.0_-_083.jpg",
# 6. Coliseo:     "https://es.wikipedia.org/wiki/Coliseo#/media/Archivo:Colosseo_2020.jpg" ,
# 7. Partenon     "https://es.wikipedia.org/wiki/Archivo:The_Parthenon_in_Athens.jpg",
# 8. Torre Eiffel:      "https://es.wikipedia.org/wiki/Archivo:Eiffelturm.JPG" ,
# 9. "https://es.wikipedia.org/wiki/Pante%C3%B3n_de_Agripa#/media/Archivo:Pantheon_Rom_1_cropped.jpg",
#
# 10. "https://es.wikipedia.org/wiki/Museos_Vaticanos#/media/Archivo:Rome_Vatican_Museums.jpg",
# 28. Museo de Victoria y Alberto:         "https://es.wikipedia.org/wiki/Museo_de_Victoria_y_Alberto#/media/Archivo:Victoria_&_Albert_Museum_Entrance,_London,_UK_-_Diliff.jpg",
# 29. Museo de Orsay:       "https://es.wikipedia.org/wiki/Museo_de_Orsay#/media/Archivo:MuseeDOrsay.jpg",
# 30. London Science museum:      "https://en.wikipedia.org/wiki/Science_Museum,_London#/media/File:Science_Museum,_Exhibition_Road_(cropped).jpg",
# 31. "https://es.wikipedia.org/wiki/Centro_Pompidou#/media/Archivo:Paris_Montmartre_Blick_aufs_Centre_Georges-Pompidou.jpg",
# 32. "https://es.wikipedia.org/wiki/Somerset#/media/Archivo:Roman_Baths_in_Bath_Spa,_England_-_July_2006.jpg",
# 33. "https://es.wikipedia.org/wiki/Palacio_de_Wilan%C3%B3w#/media/Archivo:Wilanow_palace_-_panoramio_(2).jpg"
# 34. "https://es.wikipedia.org/wiki/Palacio_de_Sch%C3%B6nbrunn#/media/Archivo:Palacio_de_Sch%C3%B6nbrunn,_Viena,_Austria,_2020-02-02,_DD_28.jpg"
# 35. "https://es.wikipedia.org/wiki/Kremlin_de_Kaz%C3%A1n#/media/Archivo:Kazan_Kremlin_exterior_view_08-2016_img1.jpg"
# 36. Museo del Prado:    "https://es.wikipedia.org/wiki/Museo_del_Prado#/media/Archivo:Museo_del_Prado_2016_(25185969599).jpg",
# 37. Kremlin de Moscu:    "https://es.wikipedia.org/wiki/Kremlin_de_Mosc%C3%BA#/media/Archivo:Moscow_05-2012_Kremlin_22.jpg",
# 38. Torre de Londres:    "https://es.wikipedia.org/wiki/Torre_de_Londres#/media/Archivo:Tower_of_London_(Foto_Hilarmont).jpg",
# 39. La alambra:        "https://es.wikipedia.org/wiki/Alhambra#/media/Archivo:Dawn_Charles_V_Palace_Alhambra_Granada_Andalusia_Spain.jpg",
# 40. Ciudad de las ciencias Valencia:        "https://es.wikipedia.org/wiki/Ciudad_de_las_Artes_y_las_Ciencias#/media/Archivo:Hemispheric_-_Valencia,_Spain_-_Jan_2007.jpg",
# 41. Royal museums greenwich:          "https://cdn-imgix.headout.com/tour/28011/TOUR-IMAGE/8aa8e7eb-9365-4132-9acc-5d0ace4b681e-14857-london-royal-museums-greenwich-day-pass-01.jpg?auto=compress&w=768&h=480&fit=min",
# 42. Museo de la batalla de Stalingrado:      "https://cdn3.despertaferro-ediciones.com/wp-content/uploads/2019/09/3.jpg",
# 43. Rijksmuseum:                "https://es.wikipedia.org/wiki/Rijksmuseum#/media/Archivo:Museo_Nacional,_%C3%81msterdam,_Pa%C3%ADses_Bajos,_2016-05-30,_DD_13-15_HDR.jpg",
# 44. Cité des sciences et de l'industrie:              "https://fr.wikipedia.org/wiki/Cit%C3%A9_des_sciences_et_de_l%27industrie#/media/Fichier:Cit%C3%A9_des_Sciences_et_de_l'Industrie_@_Parc_de_La_Villette_@_Paris_(28957995305).jpg",
#
# 45. "https://es.wikipedia.org/wiki/Museo_Nacional_de_Escocia#/media/Archivo:NMoS_Opening_day_view_into_the_Grand_Gallery_02.jpg",
#
# 127.46.  "https://es.wikipedia.org/wiki/Museo_Estatal_Ruso#/media/Archivo:Spb_06-2012_MichaelPalace.jpg",
# 129.47.  "https://es.wikipedia.org/wiki/Galer%C3%ADa_Nacional_de_Escocia#/media/Archivo:Wfm_national_gallery_scotland.jpg",
# 130.48.  "https://es.wikipedia.org/wiki/Museo_Van_Gogh#/media/Archivo:Van_Gogh_Museum_Amsterdam.jpg",
# 131.49.  "https://es.wikipedia.org/wiki/Galer%C3%ADa_Tretiakov#/media/Archivo:Moscow_05-2012_TretyakovGallery.jpg",
# 133.50.  "https://es.wikipedia.org/wiki/Castillo_de_Edimburgo#/media/Archivo:Castillo_de_Edinburgo.jpg",
#
# 134.51.  "https://es.wikipedia.org/wiki/Palacio_%C5%81azienki#/media/Archivo:PalaceOnTheWater2011.JPG",
# 135.52.  "https://es.wikipedia.org/wiki/Museo_estatal_Auschwitz-Birkenau#/media/Archivo:Birkenau_gate.JPG",
# 139.53.  "https://es.wikipedia.org/wiki/Capilla_de_Nuestra_Se%C3%B1ora_de_la_Medalla_Milagrosa#/media/Archivo:Bac_M_Miraculeuse.Autel2.jpg",
# 141.54.  "https://es.wikipedia.org/wiki/Mezquita-catedral_de_C%C3%B3rdoba#/media/Archivo:Mosque_of_Cordoba_Spain.jpg",
# 142.55.  "https://es.wikipedia.org/wiki/Real_Alc%C3%A1zar_de_Sevilla#/media/Archivo:Fachada_del_Palacio_del_rey_don_Pedro.jpg",
# 144.56.  "https://es.wikipedia.org/wiki/Catedral_de_San_Pablo_de_Londres#/media/Archivo:St_Paul's_Cathedral,_London,_England_-_Jan_2010_tower_adjusted_2.jpg",
# 146.57.  "https://es.wikipedia.org/wiki/Arco_de_Triunfo_de_Par%C3%ADs#/media/Archivo:Arc_de_Triomphe,_Paris_21_October_2010.jpg",
# 148.58.  "https://es.wikipedia.org/wiki/Palacio_Real_de_Madrid#/media/Archivo:Palacio_Real_de_Madrid_Julio_2016_(cropped).jpg",
# 150.59.  "https://es.wikipedia.org/wiki/Neuschwanstein#/media/Archivo:Neuschwanstein_castle.jpg",
# 159.60.  "https://es.wikipedia.org/wiki/Catedral_de_Mil%C3%A1n#/media/Archivo:Milan_Cathedral_from_Piazza_del_Duomo.jpg"

# %% [markdown]
# ### ENLACES
#
#
# 0.  "https://www.paris.es/catedral-notre-dame",
# 1.  "https://www.rome-museum.com/es/basilica-de-san-pedro.php",
# 2.  "https://www.paris.es/basilica-sagrado-corazon",
# 3.  "https://www.louvre.fr/es",
# 4.  "https://www.fatima.pt/es",
# 5.  "https://es.chateauversailles.fr/",
# 6.  "https://www.rome-museum.com/es/coliseo-romano.php",
# 7.  "https://acropolis-greece.com/?gclid=CjwKCAiAioifBhAXEiwApzCztsHP6c7tb5jfcDArkfMkcV7TJfriPFZ30r7Q3_gtQNos0FQ0epltUxoC1QEQAvD_BwE",
# 8.  "https://www.toureiffel.paris/es",
# 9.  "https://www.rome-museum.com/es/panteon-roma.php",
# 10. "https://www.museivaticani.va/content/museivaticani/es.html",
# 11. "https://www.padrepiodapietrelcina.com/es/santuario-padre-pio-san-giovanni-rotondo-italia/",
# 12. "https://www.britishmuseum.org/",
# 13. "https://www.tate.org.uk/visit/tate-modern",
# 14. "https://www.nationalgallery.org.uk/",
# 15. "https://es.lourdes-infotourisme.com/explorar/vivir-una-experiencia-espiritual/explorar-el-santuario/",
# 16. "https://www.koelner-dom.de/",
# 17. "https://www.sanfrancescoassisi.org/html/ita/index.php",
# 18. "https://www.nhm.ac.uk/",
# 19. "https://peterhofmuseum.ru/",
# 20. "http://www.basilicasanmarco.it/",
# 21. "https://www.hermitagemuseum.org/wps/portal/hermitage/?lng=es",
# 22. "https://sagradafamilia.org/es/",
# 23. "https://www.museivaticani.va/content/museivaticani/es.html",
# 24. "https://www.duomofirenze.it/es/",
# 25. "https://www.museoreinasofia.es/",
# 26. "https://jasnagora.pl/",
# 27. "https://www.uffizi.it/",
# 28. "https://www.vam.ac.uk/",
# 29. "https://www.musee-orsay.fr/es",
# 30. "https://www.sciencemuseum.org.uk/home",
# 31. "https://www.centrepompidou.fr/es/",
# 32. "https://www.somersethouse.org.uk/",
# 33. "https://www.wilanow-palac.pl/rezydencja",
# 34. "https://www.schoenbrunn.at/",
# 35. "https://es.wikipedia.org/wiki/Kremlin_de_Kaz%C3%A1n",
# 36. "https://www.museodelprado.es/",
# 37. "https://kremlintour.com/es/museos-del-kremlin-de-moscu",
# 38. "https://www.hrp.org.uk/tower-of-london/#gs.pc05co",
# 39. "https://www.alhambra-patronato.es/",
# 40. "https://www.cac.es/es/home.html",
# 41. "https://www.rmg.co.uk/",
# 42. "https://stalingrad-battle.ru/",
# 43. "https://www.rijksmuseum.nl/es/visit",
# 44. "https://www.cite-sciences.fr/fr/accueil",
# 45. "https://www.nms.ac.uk/national-museum-of-scotland",
# 46. "http://en.rusmuseum.ru/",
# 47. "https://www.nationalgalleries.org/nationalgallerycomplex",
# 48. "https://www.vangoghmuseum.nl/es/planifica-tu-visita",
# 49. "https://www.tretyakovgallery.ru/",
# 50. "https://es.wikipedia.org/wiki/Castillo_de_Edimburgo",
# 51. "https://www.lazienki-krolewskie.pl/pl",
# 52. "https://www.auschwitz.org/en/more/spanish/",
# 53. "https://www.chapellenotredamedelamedaillemiraculeuse.com/langues/espanol/capilla-nuestra-senora-de-la-medalla-milagrosa/",
# 54. "https://mezquita-catedraldecordoba.es/",
# 55. "https://www.alcazarsevilla.org/",
# 56. "https://www.stpauls.co.uk/",
# 57. "https://www.paris-arc-de-triomphe.fr/es/",
# 58. "https://www.patrimonionacional.es/visita/palacio-real-de-madrid",
# 59. "https://www.neuschwanstein.de/spanisch/visitante/index.htm",
# 60. "https://www.milan-museum.com/es/duomo-catedral-de-milan.php",
